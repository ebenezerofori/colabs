# %% [markdown]
# <a href="https://colab.research.google.com/github/Vankum100/colabs/blob/bms-test/%D0%94%D0%9C%D0%9F_8_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![8a.PNG](data:image/png;base64,...)

# %%
import numpy as np
from scipy import integrate
import matplotlib.pyplot as plt

# вычисление константа
def constant_term(D, la, h, wL):
    return D / ( 16*la*h* np.log( ( 4*D/wL) - 2 + (7*wL/2*D)))

# вычисление первого двойного интеграла
def first_doubleI(x, y):
    return (np.exp(-((x + w/2)/la)) * ( x0 - x) )/ ( np.square(y0 - y) + np.square(x0 - x))
# вычисление второго двойного интеграла
def second_doubleI(x, y):
    return np.exp(-((w/2 - x)/la)) * ( x0 - x) / ( np.square(y0 - y) + np.square(x0 - x))

# пределы интеграла y
def bounds_y(h):
   return [-2*h, 0]

# пределы интеграла x1
def bounds_x1(w):
    return [-w/2, 0]

# пределы интеграла x2
def bounds_x2(w):
    return [0, w/2]

# Параметры
D = 2 * (10 ** -3)
wL = 8 * ( 10 ** -4)
la = 250 * ( 10 ** -9)
h = 40 *(10 ** -9)
w = 30 * (10 ** -6)
y0 = 10 * ( 10 ** -9) 

# вычисление константа
const_part = constant_term(D,la,h,wL)


start_x0  = 15.5 * ( 10 ** -6)
end_x0 = 17.5 * ( 10 ** -6)
step = 0.05 * ( 10 ** -6) # шаг

x0_values = np.arange(start_x0, end_x0, step ) 
f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'k--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при la = 250 * ( 10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_lamda250.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
la = 1000 * ( 10 ** -9)
f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'b--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при la = 1000 * ( 10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_lamda1000.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
la = 4000 * ( 10 ** -9)
f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'r--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при la = 4000 * ( 10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_lamda4000.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
la = 16000 * ( 10 ** -9)
f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'b--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при la = 16000 * ( 10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_lamda16000.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %% [markdown]
# ![8b.PNG](data:image/png;base64,...)

# %%
la = 250 * ( 10 ** -9)
h = 10 *(10 ** -9)

f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'k--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при h = 10 *(10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_h10.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
h = 40 *(10 ** -9)

f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'b--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при h = 40 *(10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_h40.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
h = 160 *(10 ** -9)

f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'r--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при h = 160 *(10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_h160.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
h = 640 *(10 ** -9)

f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'g--')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при h = 640 *(10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_h640.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)

# %%
h = 2560 *(10 ** -9)

f0_values = []
for i in range(len(x0_values)):
  x0 = x0_values[i]
  # вычисление значений f0 для всех х0
  Idxdy_1, err1 = integrate.nquad(first_doubleI, [bounds_x1(w), bounds_y(h)])
  Idxdy_2 , err2= integrate.nquad(second_doubleI, [bounds_x2(w), bounds_y(h)])
  
  f0_val = const_part * ( Idxdy_1 + Idxdy_2 )
  f0_values.append(f0_val)


plt.plot(x0_values, f0_values , 'b-')
plt.ylabel(' значения f0')
plt.xlabel(' значения x0')
plt.title('граф зависимости f0 от x0  при h = 2560 *(10 ** -9)')
plt.show()

# пишем данные в csv файл и онлайн сконвертируем в excel 
import csv

with open('dmp8_h2560.csv', mode='w') as data_file:
    data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    data_writer.writerow(x0_values)
    data_writer.writerow(f0_values)
